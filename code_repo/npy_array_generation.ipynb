# %%
import numpy as np
import MDAnalysis as mda
import os
import pandas as pd
from code_libraries.bilayer_operations import Bilayer
from code_libraries.acyl_chain_preprocessing import *
import matplotlib.pyplot as plt

# %%
start_frame , stop_frame = 0 , 2000
frames = stop_frame

# %%
dataframe_dir = os.path.join("../" , "heavy_data_NO_GIT/dataframes/sym/")

# %%
dataframe_dir
# Out:
# '../heavy_data_NO_GIT/dataframes/sym/'

# %%
pure_dopc = Bilayer("dopc_pure" , "sym" , start_frame , stop_frame)
pure_dopc.create_universe()
pure_dopc.save_residue_positions("DOPC") 


dopc_94 = Bilayer("dopc_94" , "sym" , start_frame , stop_frame)
dopc_94.create_universe()
dopc_94.save_residue_positions("DOPC")
dopc_94.save_residue_positions("CHL1")


dopc_90 = Bilayer("dopc_90" , "sym" , start_frame , stop_frame)
dopc_90.create_universe()
dopc_90.save_residue_positions("DOPC")
dopc_90.save_residue_positions("CHL1")


dopc_85 = Bilayer("dopc_85" , "sym" , start_frame , stop_frame)
dopc_85.create_universe()
dopc_85.save_residue_positions("DOPC")
dopc_85.save_residue_positions("CHL1")

dopc_80 = Bilayer("dopc_80" , "sym" , start_frame , stop_frame)
dopc_80.create_universe()
dopc_80.save_residue_positions("DOPC")
dopc_80.save_residue_positions("CHL1")

dopc_75 = Bilayer("dopc_75" , "sym" , start_frame , stop_frame)
dopc_75.create_universe()
dopc_75.save_residue_positions("DOPC")
dopc_75.save_residue_positions("CHL1")

dopc_70 = Bilayer("dopc_70" , "sym" , start_frame , stop_frame)
dopc_70.create_universe()
dopc_70.save_residue_positions("DOPC")
dopc_70.save_residue_positions("CHL1")

dopc_65 = Bilayer("dopc_65" , "sym" , start_frame , stop_frame)
dopc_65.create_universe()
dopc_65.save_residue_positions("DOPC")
dopc_65.save_residue_positions("CHL1")

dopc_60 = Bilayer("dopc_60" , "sym" , start_frame , stop_frame)
dopc_60.create_universe()
dopc_60.save_residue_positions("DOPC")
dopc_60.save_residue_positions("CHL1")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[41], line 30
#      28 dopc_75 = Bilayer("dopc_75" , "sym" , start_frame , stop_frame)
#      29 dopc_75.create_universe()
# ---> 30 dopc_75.save_residue_positions("DOPC")
#      31 dopc_75.save_residue_positions("CHL1")
#      33 dopc_70 = Bilayer("dopc_70" , "sym" , start_frame , stop_frame)
#
# File ~/Desktop/Git_Repos/git_repo_4/bilayer_classification_project/ml_dopc/code_repo/code_libraries/bilayer_operations.py:86, in Bilayer.save_residue_positions(self, res_string)
#      83 filename = self.sys_type + "_" + self.sys_name + "_" + res_string + "_positions.npy"
#      84 filepath = os.path.join(containing_directory , filename)
# ---> 86 np.save(filepath , all_positions)
#
# File /opt/anaconda3/lib/python3.10/site-packages/numpy/lib/npyio.py:546, in save(file, arr, allow_pickle, fix_imports)
# ...
