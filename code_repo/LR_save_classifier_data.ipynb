# %%
import numpy as np
import MDAnalysis as mda
import os
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import Normalize

from code_libraries.bilayer_operations import Bilayer
from code_libraries.acyl_chain_preprocessing import *
from code_libraries.miscellaneous_functions import *

from code_libraries.predict_acyl_chains_NN_by_chain import *

# %%
start_frame , stop_frame = 0 , 2000
sys_type = "sym"
sys_name_94 = "dopc_94"
sys_name_90 = "dopc_90"
sys_name_85 = "dopc_85"
sys_name_80 = "dopc_80"
sys_name_75 = "dopc_75"
sys_name_70 = "dopc_70"
sys_name_65 = "dopc_65"

data_array_dir = os.path.join("../" , "heavy_data_NO_GIT/data_arrays")

# %% [markdown]
# ## 15pt (best calibrated)

# %%
dopc_94_sn1 = clf_lo_ld_by_chain(sys_name_94 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_94_sn2 = clf_lo_ld_by_chain(sys_name_94 , sys_type , "ft_last" , "log_reg"  , "sn2", 15 , start_frame , stop_frame)
dopc_94_sn1.process_all_input()
dopc_94_sn2.process_all_input()
dopc_94_sn1.classify(uses_predict_proba=False)
dopc_94_sn2.classify(uses_predict_proba=False)

dopc_90_sn1 = clf_lo_ld_by_chain(sys_name_90 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_90_sn2 = clf_lo_ld_by_chain(sys_name_90 , sys_type , "ft_last" , "log_reg"  , "sn2", 15 , start_frame , stop_frame)
dopc_90_sn1.process_all_input()
dopc_90_sn2.process_all_input()
dopc_90_sn1.classify(uses_predict_proba=False)
dopc_90_sn2.classify(uses_predict_proba=False)

dopc_85_sn1 = clf_lo_ld_by_chain(sys_name_85 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_85_sn2 = clf_lo_ld_by_chain(sys_name_85 , sys_type , "ft_last" , "log_reg"  , "sn2", 15, start_frame , stop_frame)
dopc_85_sn1.process_all_input()
dopc_85_sn2.process_all_input()
dopc_85_sn1.classify(uses_predict_proba=False)
dopc_85_sn2.classify(uses_predict_proba=False)

dopc_80_sn1 = clf_lo_ld_by_chain(sys_name_80 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_80_sn2 = clf_lo_ld_by_chain(sys_name_80 , sys_type , "ft_last" , "log_reg"  , "sn2", 15 , start_frame , stop_frame)
dopc_80_sn1.process_all_input()
dopc_80_sn2.process_all_input()
dopc_80_sn1.classify(uses_predict_proba=False)
dopc_80_sn2.classify(uses_predict_proba=False)

dopc_75_sn1 = clf_lo_ld_by_chain(sys_name_75 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_75_sn2 = clf_lo_ld_by_chain(sys_name_75 , sys_type , "ft_last" , "log_reg"  , "sn2", 15 , start_frame , stop_frame)
dopc_75_sn1.process_all_input()
dopc_75_sn2.process_all_input()
dopc_75_sn1.classify(uses_predict_proba=False)
dopc_75_sn2.classify(uses_predict_proba=False)

dopc_70_sn1 = clf_lo_ld_by_chain(sys_name_70 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_70_sn2 = clf_lo_ld_by_chain(sys_name_70 , sys_type , "ft_last" , "log_reg"  , "sn2", 15 , start_frame , stop_frame)
dopc_70_sn1.process_all_input()
dopc_70_sn2.process_all_input()
dopc_70_sn1.classify(uses_predict_proba=False)
dopc_70_sn2.classify(uses_predict_proba=False)

dopc_65_sn1 = clf_lo_ld_by_chain(sys_name_65 , sys_type , "ft_last" , "log_reg"  , "sn1", 15 , start_frame , stop_frame)
dopc_65_sn2 = clf_lo_ld_by_chain(sys_name_65 , sys_type , "ft_last" , "log_reg"  , "sn2", 15 , start_frame , stop_frame)
dopc_65_sn1.process_all_input()
dopc_65_sn2.process_all_input()
dopc_65_sn1.classify(uses_predict_proba=False)
dopc_65_sn2.classify(uses_predict_proba=False)

# %%
dopc_94_box_dim = dopc_94_sn1.box_dimensions
dopc_94_sn1_processed_acyl_coms = dopc_94_sn1.processed_acyl_coms
dopc_94_sn1_processed_acyl_c4 = dopc_94_sn1.processed_acyl_c4
dopc_94_sn1_processed_chol_coms = dopc_94_sn1.processed_chol_coms
dopc_94_sn1_processed_chol_heads = dopc_94_sn1.processed_chol_heads
dopc_94_sn1_predictions_probs = dopc_94_sn1.prediction_probs
dopc_94_sn1_prediction_labels = dopc_94_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_box_dim.npy") , dopc_94_box_dim)
np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_acyl_coms.npy") , dopc_94_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_acyl_c4.npy") , dopc_94_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_chol_coms.npy") , dopc_94_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_chol_heads.npy") , dopc_94_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_prediction_probs.npy") , dopc_94_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_94_sn1_ft_last_15pt_prediction_labels.npy") , dopc_94_sn1_prediction_labels)


dopc_94_box_dim = dopc_94_sn2.box_dimensions
dopc_94_sn2_processed_acyl_coms = dopc_94_sn2.processed_acyl_coms
dopc_94_sn2_processed_acyl_c4 = dopc_94_sn2.processed_acyl_c4
dopc_94_sn2_processed_chol_coms = dopc_94_sn2.processed_chol_coms
dopc_94_sn2_processed_chol_heads = dopc_94_sn2.processed_chol_heads
dopc_94_sn2_predictions_probs = dopc_94_sn2.prediction_probs
dopc_94_sn2_prediction_labels = dopc_94_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_box_dim.npy") , dopc_94_box_dim)
np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_acyl_coms.npy") , dopc_94_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_acyl_c4.npy") , dopc_94_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_chol_coms.npy") , dopc_94_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_chol_heads.npy") , dopc_94_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_prediction_probs.npy") , dopc_94_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_94_sn2_ft_last_15pt_prediction_labels.npy") , dopc_94_sn2_prediction_labels)

# %%
dopc_90_box_dim = dopc_90_sn1.box_dimensions
dopc_90_sn1_processed_acyl_coms = dopc_90_sn1.processed_acyl_coms
dopc_90_sn1_processed_acyl_c4 = dopc_90_sn1.processed_acyl_c4
dopc_90_sn1_processed_chol_coms = dopc_90_sn1.processed_chol_coms
dopc_90_sn1_processed_chol_heads = dopc_90_sn1.processed_chol_heads
dopc_90_sn1_predictions_probs = dopc_90_sn1.prediction_probs
dopc_90_sn1_prediction_labels = dopc_90_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_box_dim.npy") , dopc_90_box_dim)
np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_acyl_coms.npy") , dopc_90_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_acyl_c4.npy") , dopc_90_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_chol_coms.npy") , dopc_90_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_chol_heads.npy") , dopc_90_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_prediction_probs.npy") , dopc_90_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_90_sn1_ft_last_15pt_prediction_labels.npy") , dopc_90_sn1_prediction_labels)



dopc_90_box_dim = dopc_90_sn2.box_dimensions
dopc_90_sn2_processed_acyl_coms = dopc_90_sn2.processed_acyl_coms
dopc_90_sn2_processed_acyl_c4 = dopc_90_sn2.processed_acyl_c4
dopc_90_sn2_processed_chol_coms = dopc_90_sn2.processed_chol_coms
dopc_90_sn2_processed_chol_heads = dopc_90_sn2.processed_chol_heads
dopc_90_sn2_predictions_probs = dopc_90_sn2.prediction_probs
dopc_90_sn2_prediction_labels = dopc_90_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_box_dim.npy") , dopc_90_box_dim)
np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_acyl_coms.npy") , dopc_90_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_acyl_c4.npy") , dopc_90_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_chol_coms.npy") , dopc_90_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_chol_heads.npy") , dopc_90_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_prediction_probs.npy") , dopc_90_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_90_sn2_ft_last_15pt_prediction_labels.npy") , dopc_90_sn2_prediction_labels)

# %%
dopc_85_box_dim = dopc_85_sn1.box_dimensions
dopc_85_sn1_processed_acyl_coms = dopc_85_sn1.processed_acyl_coms
dopc_85_sn1_processed_acyl_c4 = dopc_85_sn1.processed_acyl_c4
dopc_85_sn1_processed_chol_coms = dopc_85_sn1.processed_chol_coms
dopc_85_sn1_processed_chol_heads = dopc_85_sn1.processed_chol_heads
dopc_85_sn1_predictions_probs = dopc_85_sn1.prediction_probs
dopc_85_sn1_prediction_labels = dopc_85_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_box_dim.npy") , dopc_85_box_dim)
np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_acyl_coms.npy") , dopc_85_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_acyl_c4.npy") , dopc_85_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_chol_coms.npy") , dopc_85_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_chol_heads.npy") , dopc_85_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_prediction_probs.npy") , dopc_85_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_85_sn1_ft_last_15pt_prediction_labels.npy") , dopc_85_sn1_prediction_labels)



dopc_85_box_dim = dopc_85_sn2.box_dimensions
dopc_85_sn2_processed_acyl_coms = dopc_85_sn2.processed_acyl_coms
dopc_85_sn2_processed_acyl_c4 = dopc_85_sn2.processed_acyl_c4
dopc_85_sn2_processed_chol_coms = dopc_85_sn2.processed_chol_coms
dopc_85_sn2_processed_chol_heads = dopc_85_sn2.processed_chol_heads
dopc_85_sn2_predictions_probs = dopc_85_sn2.prediction_probs
dopc_85_sn2_prediction_labels = dopc_85_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_box_dim.npy") , dopc_85_box_dim)
np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_acyl_coms.npy") , dopc_85_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_acyl_c4.npy") , dopc_85_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_chol_coms.npy") , dopc_85_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_chol_heads.npy") , dopc_85_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_prediction_probs.npy") , dopc_85_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_85_sn2_ft_last_15pt_prediction_labels.npy") , dopc_85_sn2_prediction_labels)

# %%
dopc_80_box_dim = dopc_80_sn1.box_dimensions
dopc_80_sn1_processed_acyl_coms = dopc_80_sn1.processed_acyl_coms
dopc_80_sn1_processed_acyl_c4 = dopc_80_sn1.processed_acyl_c4
dopc_80_sn1_processed_chol_coms = dopc_80_sn1.processed_chol_coms
dopc_80_sn1_processed_chol_heads = dopc_80_sn1.processed_chol_heads
dopc_80_sn1_predictions_probs = dopc_80_sn1.prediction_probs
dopc_80_sn1_prediction_labels = dopc_80_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_box_dim.npy") , dopc_80_box_dim)
np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_acyl_coms.npy") , dopc_80_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_acyl_c4.npy") , dopc_80_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_chol_coms.npy") , dopc_80_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_chol_heads.npy") , dopc_80_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_prediction_probs.npy") , dopc_80_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_80_sn1_ft_last_15pt_prediction_labels.npy") , dopc_80_sn1_prediction_labels)



dopc_80_box_dim = dopc_80_sn2.box_dimensions
dopc_80_sn2_processed_acyl_coms = dopc_80_sn2.processed_acyl_coms
dopc_80_sn2_processed_acyl_c4 = dopc_80_sn2.processed_acyl_c4
dopc_80_sn2_processed_chol_coms = dopc_80_sn2.processed_chol_coms
dopc_80_sn2_processed_chol_heads = dopc_80_sn2.processed_chol_heads
dopc_80_sn2_predictions_probs = dopc_80_sn2.prediction_probs
dopc_80_sn2_prediction_labels = dopc_80_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_box_dim.npy") , dopc_80_box_dim)
np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_acyl_coms.npy") , dopc_80_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_acyl_c4.npy") , dopc_80_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_chol_coms.npy") , dopc_80_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_chol_heads.npy") , dopc_80_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_prediction_probs.npy") , dopc_80_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_80_sn2_ft_last_15pt_prediction_labels.npy") , dopc_80_sn2_prediction_labels)

# %%
dopc_75_box_dim = dopc_75_sn1.box_dimensions
dopc_75_sn1_processed_acyl_coms = dopc_75_sn1.processed_acyl_coms
dopc_75_sn1_processed_acyl_c4 = dopc_75_sn1.processed_acyl_c4
dopc_75_sn1_processed_chol_coms = dopc_75_sn1.processed_chol_coms
dopc_75_sn1_processed_chol_heads = dopc_75_sn1.processed_chol_heads
dopc_75_sn1_predictions_probs = dopc_75_sn1.prediction_probs
dopc_75_sn1_prediction_labels = dopc_75_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_box_dim.npy") , dopc_75_box_dim)
np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_acyl_coms.npy") , dopc_75_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_acyl_c4.npy") , dopc_75_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_chol_coms.npy") , dopc_75_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_chol_heads.npy") , dopc_75_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_prediction_probs.npy") , dopc_75_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_75_sn1_ft_last_15pt_prediction_labels.npy") , dopc_75_sn1_prediction_labels)



dopc_75_box_dim = dopc_75_sn2.box_dimensions
dopc_75_sn2_processed_acyl_coms = dopc_75_sn2.processed_acyl_coms
dopc_75_sn2_processed_acyl_c4 = dopc_75_sn2.processed_acyl_c4
dopc_75_sn2_processed_chol_coms = dopc_75_sn2.processed_chol_coms
dopc_75_sn2_processed_chol_heads = dopc_75_sn2.processed_chol_heads
dopc_75_sn2_predictions_probs = dopc_75_sn2.prediction_probs
dopc_75_sn2_prediction_labels = dopc_75_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_box_dim.npy") , dopc_75_box_dim)
np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_acyl_coms.npy") , dopc_75_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_acyl_c4.npy") , dopc_75_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_chol_coms.npy") , dopc_75_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_chol_heads.npy") , dopc_75_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_prediction_probs.npy") , dopc_75_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_75_sn2_ft_last_15pt_prediction_labels.npy") , dopc_75_sn2_prediction_labels)

# %%
dopc_70_box_dim = dopc_70_sn1.box_dimensions
dopc_70_sn1_processed_acyl_coms = dopc_70_sn1.processed_acyl_coms
dopc_70_sn1_processed_acyl_c4 = dopc_70_sn1.processed_acyl_c4
dopc_70_sn1_processed_chol_coms = dopc_70_sn1.processed_chol_coms
dopc_70_sn1_processed_chol_heads = dopc_70_sn1.processed_chol_heads
dopc_70_sn1_predictions_probs = dopc_70_sn1.prediction_probs
dopc_70_sn1_prediction_labels = dopc_70_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_box_dim.npy") , dopc_70_box_dim)
np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_acyl_coms.npy") , dopc_70_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_acyl_c4.npy") , dopc_70_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_chol_coms.npy") , dopc_70_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_chol_heads.npy") , dopc_70_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_prediction_probs.npy") , dopc_70_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_70_sn1_ft_last_15pt_prediction_labels.npy") , dopc_70_sn1_prediction_labels)



dopc_70_box_dim = dopc_70_sn2.box_dimensions
dopc_70_sn2_processed_acyl_coms = dopc_70_sn2.processed_acyl_coms
dopc_70_sn2_processed_acyl_c4 = dopc_70_sn2.processed_acyl_c4
dopc_70_sn2_processed_chol_coms = dopc_70_sn2.processed_chol_coms
dopc_70_sn2_processed_chol_heads = dopc_70_sn2.processed_chol_heads
dopc_70_sn2_predictions_probs = dopc_70_sn2.prediction_probs
dopc_70_sn2_prediction_labels = dopc_70_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_box_dim.npy") , dopc_70_box_dim)
np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_acyl_coms.npy") , dopc_70_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_acyl_c4.npy") , dopc_70_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_chol_coms.npy") , dopc_70_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_chol_heads.npy") , dopc_70_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_prediction_probs.npy") , dopc_70_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_70_sn2_ft_last_15pt_prediction_labels.npy") , dopc_70_sn2_prediction_labels)

# %%
dopc_65_box_dim = dopc_65_sn1.box_dimensions
dopc_65_sn1_processed_acyl_coms = dopc_65_sn1.processed_acyl_coms
dopc_65_sn1_processed_acyl_c4 = dopc_65_sn1.processed_acyl_c4
dopc_65_sn1_processed_chol_coms = dopc_65_sn1.processed_chol_coms
dopc_65_sn1_processed_chol_heads = dopc_65_sn1.processed_chol_heads
dopc_65_sn1_predictions_probs = dopc_65_sn1.prediction_probs
dopc_65_sn1_prediction_labels = dopc_65_sn1.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_box_dim.npy") , dopc_65_box_dim)
np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_acyl_coms.npy") , dopc_65_sn1_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_acyl_c4.npy") , dopc_65_sn1_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_chol_coms.npy") , dopc_65_sn1_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_chol_heads.npy") , dopc_65_sn1_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_prediction_probs.npy") , dopc_65_sn1_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_65_sn1_ft_last_15pt_prediction_labels.npy") , dopc_65_sn1_prediction_labels)



dopc_65_box_dim = dopc_65_sn2.box_dimensions
dopc_65_sn2_processed_acyl_coms = dopc_65_sn2.processed_acyl_coms
dopc_65_sn2_processed_acyl_c4 = dopc_65_sn2.processed_acyl_c4
dopc_65_sn2_processed_chol_coms = dopc_65_sn2.processed_chol_coms
dopc_65_sn2_processed_chol_heads = dopc_65_sn2.processed_chol_heads
dopc_65_sn2_predictions_probs = dopc_65_sn2.prediction_probs
dopc_65_sn2_prediction_labels = dopc_65_sn2.prediction_labels

np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_box_dim.npy") , dopc_65_box_dim)
np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_acyl_coms.npy") , dopc_65_sn2_processed_acyl_coms)
np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_acyl_c4.npy") , dopc_65_sn2_processed_acyl_c4)
np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_chol_coms.npy") , dopc_65_sn2_processed_chol_coms)
np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_chol_heads.npy") , dopc_65_sn2_processed_chol_heads)
np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_prediction_probs.npy") , dopc_65_sn2_predictions_probs)
np.save(os.path.join(data_array_dir , "dopc_65_sn2_ft_last_15pt_prediction_labels.npy") , dopc_65_sn2_prediction_labels)
