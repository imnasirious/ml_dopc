# %%
import numpy as np
import MDAnalysis as mda
import os
import pandas as pd
from code_libraries.bilayer_operations import Bilayer
from code_libraries.acyl_chain_preprocessing import *
import matplotlib.pyplot as plt

# %%
start_frame , stop_frame = 0 , 2000
frames = stop_frame

sn1_indices = [41, 42 , 43]
sn1_indices.extend(i for i in range(91 ,134))
sn1_indices_carbon_only = np.array([42 , 92, 95, 98, 101 , 104,107, 110,  112, 114 , 117 , 120 , 123, 126, 129,   132])
sn1_indices_carbon_only = sn1_indices_carbon_only

sn2_indices = [32, 33 , 34]
sn2_indices.extend(i for i in range(44 ,91))
sn2_indices_carbon_only = np.array([33 , 45 , 48 , 51 , 54 , 57 , 60 , 63 , 65 , 67 , 70 , 73 , 76 , 79 , 82 , 85])
sn2_indices_carbon_only = sn2_indices_carbon_only
lower_z_axis = np.array([0 ,0 , 1])
upper_z_axis = np.array([0 , 0 , 1])

dopc_pure = Bilayer("dopc_pure" , "sym" , start_frame , stop_frame)
dopc_pure.create_universe()

dopc_60 = Bilayer("dopc_60" , "sym" , start_frame , stop_frame)
dopc_60.create_universe()

dopc_pure.cleave_leaflets()
dopc_60.cleave_leaflets()


dopc_pure_lower_leaflet = dopc_pure.lower_leaflet
dopc_pure_upper_leaflet = dopc_pure.upper_leaflet

dopc_60_lower_leaflet = dopc_60.lower_leaflet[0]
dopc_60_upper_leaflet = dopc_60.upper_leaflet[0]

# %%
dataframe_dir = os.path.join("../" , "heavy_data_NO_GIT/dataframes/sym/")

# %%
n_red_3pt = int(0.999*stop_frame)
n_red_5pt = int(0.998*stop_frame)
n_red_7pt = int(0.997*stop_frame)
n_red_9pt = int(0.996*stop_frame)
n_red_11pt= int(0.995 * stop_frame)
n_red_13pt = int(0.994 * stop_frame)
n_red_15pt = int(0.993 * stop_frame)
n_red_17pt = int(0.992*stop_frame)
# n_red_19pt = int(0.991*stop_frame)z
# n_red_21pt = int(0.990*stop_frame)

n_red_original = int(1*stop_frame)

# %%
####possibly redundant step but this is just how things were written


pure_dopc_sn1_lower_op_ft_raw = op_height_df(dopc_pure_lower_leaflet , "sn1" , n_red_original , is_pure=True, heights = True)
pure_dopc_sn1_upper_op_ft_raw = op_height_df(dopc_pure_upper_leaflet , "sn1" , n_red_original , is_pure=True, heights = True)

dopc_60_sn1_lower_op_ft_raw = op_height_df(dopc_60_lower_leaflet , "sn1" , n_red_original , is_pure=False, heights = True)
dopc_60_sn1_upper_op_ft_raw = op_height_df(dopc_60_upper_leaflet , "sn1" , n_red_original , is_pure=False, heights = True)

pure_dopc_sn2_lower_op_ft_raw = op_height_df(dopc_pure_lower_leaflet , "sn2" , n_red_original , is_pure=True, heights = True)
pure_dopc_sn2_upper_op_ft_raw = op_height_df(dopc_pure_upper_leaflet , "sn2" , n_red_original , is_pure=True, heights = True)

dopc_60_sn2_lower_op_ft_raw = op_height_df(dopc_60_lower_leaflet , "sn2" , n_red_original , is_pure=False, heights = True)
dopc_60_sn2_upper_op_ft_raw = op_height_df(dopc_60_upper_leaflet , "sn2" , n_red_original , is_pure=False, heights = True)

# %% [markdown]
# ### (RAW DATA)

# %%
pure_dopc_sn1_both_leaflets_all_convolved_ft_raw = pd.concat([pure_dopc_sn1_lower_op_ft_raw,
                                                               pure_dopc_sn1_upper_op_ft_raw],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_raw = pd.concat([pure_dopc_sn2_lower_op_ft_raw,
                                                               pure_dopc_sn2_upper_op_ft_raw],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_raw = pd.concat([dopc_60_sn1_lower_op_ft_raw,
                                                               dopc_60_sn1_upper_op_ft_raw],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_raw = pd.concat([dopc_60_sn2_lower_op_ft_raw,
                                                               dopc_60_sn2_upper_op_ft_raw],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_raw = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_raw , dopc_60_sn1_both_leaflets_all_convolved_ft_raw] , axis = 0 , ignore_index=True)
sn2_combined_ft_raw =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_raw , dopc_60_sn2_both_leaflets_all_convolved_ft_raw] , axis = 0 , ignore_index=True)

sn1_only_df_ft_raw_path = os.path.join(dataframe_dir , "training_sn1_ft_raw.csv")
sn2_only_df_ft_raw_path = os.path.join(dataframe_dir , "training_sn2_ft_raw.csv")


sn1_combined_ft_raw.to_csv(sn1_only_df_ft_raw_path)
sn2_combined_ft_raw.to_csv(sn2_only_df_ft_raw_path)


# sn1_sn2_df_ft_raw = combine_sn1_sn2(sn1_combined_ft_raw , sn2_combined_ft_raw)

# sn1_sn2_dfs_path_ft_raw = os.path.join(dataframe_dir , "training_sn1_sn2_raw.csv")

# sn1_sn2_df_ft_raw.to_csv(sn1_sn2_dfs_path_ft_raw)

# %% [markdown]
# ### 3 pt

# %%
pure_dopc_sn1_lower_op_ft_3pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_3pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_3pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_3pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_3pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_3pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_3pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_3pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_3pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_3pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_3pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_3pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_3pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_3pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_3pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_3pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_3pt = pd.concat([pure_dopc_sn1_lower_op_ft_3pt,
                                                               pure_dopc_sn1_upper_op_ft_3pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_3pt = pd.concat([pure_dopc_sn2_lower_op_ft_3pt,
                                                               pure_dopc_sn2_upper_op_ft_3pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_3pt = pd.concat([dopc_60_sn1_lower_op_ft_3pt,
                                                               dopc_60_sn1_upper_op_ft_3pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_3pt = pd.concat([dopc_60_sn2_lower_op_ft_3pt,
                                                               dopc_60_sn2_upper_op_ft_3pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_3pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_3pt , dopc_60_sn1_both_leaflets_all_convolved_ft_3pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_3pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_3pt , dopc_60_sn2_both_leaflets_all_convolved_ft_3pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_3pt_path = os.path.join(dataframe_dir , "training_sn1_ft_3pt.csv")
sn2_only_df_ft_3pt_path = os.path.join(dataframe_dir , "training_sn2_ft_3pt.csv")


sn1_combined_ft_3pt.to_csv(sn1_only_df_ft_3pt_path)
sn2_combined_ft_3pt.to_csv(sn2_only_df_ft_3pt_path)

# sn1_sn2_df_ft_3pt = combine_sn1_sn2(sn1_combined_ft_3pt , sn2_combined_ft_3pt)

# sn1_sn2_dfs_path_ft_3pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_3pt.csv")

# sn1_sn2_df_ft_3pt.to_csv(sn1_sn2_dfs_path_ft_3pt)

# %% [markdown]
# ### 5pt

# %%
pure_dopc_sn1_lower_op_ft_5pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_5pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_5pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_5pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_5pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_5pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_5pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_5pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_5pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_5pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_5pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_5pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_5pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_5pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_5pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_5pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_5pt = pd.concat([pure_dopc_sn1_lower_op_ft_5pt,
                                                               pure_dopc_sn1_upper_op_ft_5pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_5pt = pd.concat([pure_dopc_sn2_lower_op_ft_5pt,
                                                               pure_dopc_sn2_upper_op_ft_5pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_5pt = pd.concat([dopc_60_sn1_lower_op_ft_5pt,
                                                               dopc_60_sn1_upper_op_ft_5pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_5pt = pd.concat([dopc_60_sn2_lower_op_ft_5pt,
                                                               dopc_60_sn2_upper_op_ft_5pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_5pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_5pt , dopc_60_sn1_both_leaflets_all_convolved_ft_5pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_5pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_5pt , dopc_60_sn2_both_leaflets_all_convolved_ft_5pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_5pt_path = os.path.join(dataframe_dir , "training_sn1_ft_5pt.csv")
sn2_only_df_ft_5pt_path = os.path.join(dataframe_dir , "training_sn2_ft_5pt.csv")


sn1_combined_ft_5pt.to_csv(sn1_only_df_ft_5pt_path)
sn2_combined_ft_5pt.to_csv(sn2_only_df_ft_5pt_path)

# sn1_sn2_df_ft_5pt = combine_sn1_sn2(sn1_combined_ft_5pt , sn2_combined_ft_5pt)

# sn1_sn2_dfs_path_ft_5pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_5pt.csv")

# sn1_sn2_df_ft_5pt.to_csv(sn1_sn2_dfs_path_ft_5pt)

# %% [markdown]
# ### 7 pt

# %%
pure_dopc_sn1_lower_op_ft_7pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_7pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_7pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_7pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_7pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_7pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_7pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_7pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_7pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_7pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_7pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_7pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_7pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_7pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_7pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_7pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_7pt = pd.concat([pure_dopc_sn1_lower_op_ft_7pt,
                                                               pure_dopc_sn1_upper_op_ft_7pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_7pt = pd.concat([pure_dopc_sn2_lower_op_ft_7pt,
                                                               pure_dopc_sn2_upper_op_ft_7pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_7pt = pd.concat([dopc_60_sn1_lower_op_ft_7pt,
                                                               dopc_60_sn1_upper_op_ft_7pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_7pt = pd.concat([dopc_60_sn2_lower_op_ft_7pt,
                                                               dopc_60_sn2_upper_op_ft_7pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_7pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_7pt , dopc_60_sn1_both_leaflets_all_convolved_ft_7pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_7pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_7pt , dopc_60_sn2_both_leaflets_all_convolved_ft_7pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_7pt_path = os.path.join(dataframe_dir , "training_sn1_ft_7pt.csv")
sn2_only_df_ft_7pt_path = os.path.join(dataframe_dir , "training_sn2_ft_7pt.csv")


sn1_combined_ft_7pt.to_csv(sn1_only_df_ft_7pt_path)
sn2_combined_ft_7pt.to_csv(sn2_only_df_ft_7pt_path)

# sn1_sn2_df_ft_7pt = combine_sn1_sn2(sn1_combined_ft_7pt , sn2_combined_ft_7pt)

# sn1_sn2_dfs_path_ft_7pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_7pt.csv")

# sn1_sn2_df_ft_7pt.to_csv(sn1_sn2_dfs_path_ft_7pt)

# %% [markdown]
# ### 9 pt

# %%
pure_dopc_sn1_lower_op_ft_9pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_9pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_9pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_9pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_9pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_9pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_9pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_9pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_9pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_9pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_9pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_9pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_9pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_9pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_9pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_9pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_9pt = pd.concat([pure_dopc_sn1_lower_op_ft_9pt,
                                                               pure_dopc_sn1_upper_op_ft_9pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_9pt = pd.concat([pure_dopc_sn2_lower_op_ft_9pt,
                                                               pure_dopc_sn2_upper_op_ft_9pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_9pt = pd.concat([dopc_60_sn1_lower_op_ft_9pt,
                                                               dopc_60_sn1_upper_op_ft_9pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_9pt = pd.concat([dopc_60_sn2_lower_op_ft_9pt,
                                                               dopc_60_sn2_upper_op_ft_9pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_9pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_9pt , dopc_60_sn1_both_leaflets_all_convolved_ft_9pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_9pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_9pt , dopc_60_sn2_both_leaflets_all_convolved_ft_9pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_9pt_path = os.path.join(dataframe_dir , "training_sn1_ft_9pt.csv")
sn2_only_df_ft_9pt_path = os.path.join(dataframe_dir , "training_sn2_ft_9pt.csv")


sn1_combined_ft_9pt.to_csv(sn1_only_df_ft_9pt_path)
sn2_combined_ft_9pt.to_csv(sn2_only_df_ft_9pt_path)

# sn1_sn2_df_ft_9pt = combine_sn1_sn2(sn1_combined_ft_9pt , sn2_combined_ft_9pt)

# sn1_sn2_dfs_path_ft_9pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_9pt.csv")

# sn1_sn2_df_ft_9pt.to_csv(sn1_sn2_dfs_path_ft_9pt)

# %% [markdown]
# ### 11pt

# %%
pure_dopc_sn1_lower_op_ft_11pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_11pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_11pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_11pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_11pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_11pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_11pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_11pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_11pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_11pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_11pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_11pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_11pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_11pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_11pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_11pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_11pt = pd.concat([pure_dopc_sn1_lower_op_ft_11pt,
                                                               pure_dopc_sn1_upper_op_ft_11pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_11pt = pd.concat([pure_dopc_sn2_lower_op_ft_11pt,
                                                               pure_dopc_sn2_upper_op_ft_11pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_11pt = pd.concat([dopc_60_sn1_lower_op_ft_11pt,
                                                               dopc_60_sn1_upper_op_ft_11pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_11pt = pd.concat([dopc_60_sn2_lower_op_ft_11pt,
                                                               dopc_60_sn2_upper_op_ft_11pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_11pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_11pt , dopc_60_sn1_both_leaflets_all_convolved_ft_11pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_11pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_11pt , dopc_60_sn2_both_leaflets_all_convolved_ft_11pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_11pt_path = os.path.join(dataframe_dir , "training_sn1_ft_11pt.csv")
sn2_only_df_ft_11pt_path = os.path.join(dataframe_dir , "training_sn2_ft_11pt.csv")


sn1_combined_ft_11pt.to_csv(sn1_only_df_ft_11pt_path)
sn2_combined_ft_11pt.to_csv(sn2_only_df_ft_11pt_path)


# sn1_sn2_df_ft_11pt = combine_sn1_sn2(sn1_combined_ft_11pt , sn2_combined_ft_11pt)

# sn1_sn2_dfs_path_ft_11pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_11pt.csv")

# sn1_sn2_df_ft_11pt.to_csv(sn1_sn2_dfs_path_ft_11pt)

# %% [markdown]
# ### 13pt

# %%
pure_dopc_sn1_lower_op_ft_13pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_13pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_13pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_13pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_13pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_13pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_13pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_13pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_13pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_13pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_13pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_13pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_13pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_13pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_13pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_13pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_13pt = pd.concat([pure_dopc_sn1_lower_op_ft_13pt,
                                                               pure_dopc_sn1_upper_op_ft_13pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_13pt = pd.concat([pure_dopc_sn2_lower_op_ft_13pt,
                                                               pure_dopc_sn2_upper_op_ft_13pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_13pt = pd.concat([dopc_60_sn1_lower_op_ft_13pt,
                                                               dopc_60_sn1_upper_op_ft_13pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_13pt = pd.concat([dopc_60_sn2_lower_op_ft_13pt,
                                                               dopc_60_sn2_upper_op_ft_13pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_13pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_13pt , dopc_60_sn1_both_leaflets_all_convolved_ft_13pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_13pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_13pt , dopc_60_sn2_both_leaflets_all_convolved_ft_13pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_13pt_path = os.path.join(dataframe_dir , "training_sn1_ft_13pt.csv")
sn2_only_df_ft_13pt_path = os.path.join(dataframe_dir , "training_sn2_ft_13pt.csv")


sn1_combined_ft_13pt.to_csv(sn1_only_df_ft_13pt_path)
sn2_combined_ft_13pt.to_csv(sn2_only_df_ft_13pt_path)


# sn1_sn2_df_ft_13pt = combine_sn1_sn2(sn1_combined_ft_13pt , sn2_combined_ft_13pt)

# sn1_sn2_dfs_path_ft_13pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_13pt.csv")

# sn1_sn2_df_ft_13pt.to_csv(sn1_sn2_dfs_path_ft_13pt)

# %% [markdown]
# ### 15pt

# %%
pure_dopc_sn1_lower_op_ft_15pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_15pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_15pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_15pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_15pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_15pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_15pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_15pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_15pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_15pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_15pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_15pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_15pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_15pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_15pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_15pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_15pt = pd.concat([pure_dopc_sn1_lower_op_ft_15pt,
                                                               pure_dopc_sn1_upper_op_ft_15pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_15pt = pd.concat([pure_dopc_sn2_lower_op_ft_15pt,
                                                               pure_dopc_sn2_upper_op_ft_15pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_15pt = pd.concat([dopc_60_sn1_lower_op_ft_15pt,
                                                               dopc_60_sn1_upper_op_ft_15pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_15pt = pd.concat([dopc_60_sn2_lower_op_ft_15pt,
                                                               dopc_60_sn2_upper_op_ft_15pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_15pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_15pt , dopc_60_sn1_both_leaflets_all_convolved_ft_15pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_15pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_15pt , dopc_60_sn2_both_leaflets_all_convolved_ft_15pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_15pt_path = os.path.join(dataframe_dir , "training_sn1_ft_15pt.csv")
sn2_only_df_ft_15pt_path = os.path.join(dataframe_dir , "training_sn2_ft_15pt.csv")


sn1_combined_ft_15pt.to_csv(sn1_only_df_ft_15pt_path)
sn2_combined_ft_15pt.to_csv(sn2_only_df_ft_15pt_path)


# sn1_sn2_df_ft_15pt = combine_sn1_sn2(sn1_combined_ft_15pt , sn2_combined_ft_15pt)

# sn1_sn2_dfs_path_ft_15pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_15pt.csv")

# sn1_sn2_df_ft_15pt.to_csv(sn1_sn2_dfs_path_ft_15pt)

# %% [markdown]
# ### 17pt

# %%
pure_dopc_sn1_lower_op_ft_17pt = convolve_features_valid(pure_dopc_sn1_lower_op_ft_raw , n_red_17pt , stop_frame , label_type="pure" )
pure_dopc_sn1_upper_op_ft_17pt = convolve_features_valid(pure_dopc_sn1_upper_op_ft_raw , n_red_17pt , stop_frame, label_type="pure" )

pure_dopc_sn2_lower_op_ft_17pt = convolve_features_valid(pure_dopc_sn2_lower_op_ft_raw , n_red_17pt , stop_frame, label_type="pure")
pure_dopc_sn2_upper_op_ft_17pt = convolve_features_valid(pure_dopc_sn2_upper_op_ft_raw , n_red_17pt , stop_frame, label_type="pure" )

dopc_60_sn1_lower_op_ft_17pt = convolve_features_valid(dopc_60_sn1_lower_op_ft_raw , n_red_17pt , stop_frame, label_type="not pure")
dopc_60_sn1_upper_op_ft_17pt = convolve_features_valid(dopc_60_sn1_upper_op_ft_raw , n_red_17pt , stop_frame, label_type="not pure")

dopc_60_sn2_lower_op_ft_17pt = convolve_features_valid(dopc_60_sn2_lower_op_ft_raw , n_red_17pt , stop_frame, label_type="not pure")
dopc_60_sn2_upper_op_ft_17pt = convolve_features_valid(dopc_60_sn2_upper_op_ft_raw , n_red_17pt , stop_frame, label_type="not pure")

pure_dopc_sn1_both_leaflets_all_convolved_ft_17pt = pd.concat([pure_dopc_sn1_lower_op_ft_17pt,
                                                               pure_dopc_sn1_upper_op_ft_17pt],
                                                              axis = 0 , ignore_index = True)

pure_dopc_sn2_both_leaflets_all_convolved_ft_17pt = pd.concat([pure_dopc_sn2_lower_op_ft_17pt,
                                                               pure_dopc_sn2_upper_op_ft_17pt],
                                                              axis = 0 , ignore_index = True)


dopc_60_sn1_both_leaflets_all_convolved_ft_17pt = pd.concat([dopc_60_sn1_lower_op_ft_17pt,
                                                               dopc_60_sn1_upper_op_ft_17pt],
                                                              axis = 0 , ignore_index = True)

dopc_60_sn2_both_leaflets_all_convolved_ft_17pt = pd.concat([dopc_60_sn2_lower_op_ft_17pt,
                                                               dopc_60_sn2_upper_op_ft_17pt],
                                                              axis = 0 , ignore_index = True)

sn1_combined_ft_17pt = pd.concat([pure_dopc_sn1_both_leaflets_all_convolved_ft_17pt , dopc_60_sn1_both_leaflets_all_convolved_ft_17pt] , axis = 0 , ignore_index=True)
sn2_combined_ft_17pt =  pd.concat([pure_dopc_sn2_both_leaflets_all_convolved_ft_17pt , dopc_60_sn2_both_leaflets_all_convolved_ft_17pt] , axis = 0 , ignore_index=True)


sn1_only_df_ft_17pt_path = os.path.join(dataframe_dir , "training_sn1_ft_17pt.csv")
sn2_only_df_ft_17pt_path = os.path.join(dataframe_dir , "training_sn2_ft_17pt.csv")


sn1_combined_ft_17pt.to_csv(sn1_only_df_ft_17pt_path)
sn2_combined_ft_17pt.to_csv(sn2_only_df_ft_17pt_path)


# sn1_sn2_df_ft_17pt = combine_sn1_sn2(sn1_combined_ft_17pt , sn2_combined_ft_17pt)

# sn1_sn2_dfs_path_ft_17pt = os.path.join(dataframe_dir , "training_sn1_sn2_ft_17pt.csv")

# sn1_sn2_df_ft_17pt.to_csv(sn1_sn2_dfs_path_ft_17pt)
